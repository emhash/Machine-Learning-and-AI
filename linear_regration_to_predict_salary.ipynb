# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('datasets/salary_dataset.csv')
df.sample(4)
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 7            7              3.3   54446.0
# 4            4              2.3   39892.0
# 29          29             10.6  121873.0
# 16          16              5.2   66030.0

# %%
print(df.isna().sum())
df = df.iloc[:, 1:]
df.sample(3)
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64
#     YearsExperience    Salary
# 28             10.4  122392.0
# 7               3.3   54446.0
# 4               2.3   39892.0

# %%
plt.scatter(df['YearsExperience'] ,df['Salary'])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

model = LinearRegression()

X = df.iloc[: , :1]
y = df['Salary']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

x_train.shape, y_train.shape
# Out:
# ((24, 1), (24,))

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_test # Testing Data
# Out:
# 15     67939.0
# 5      56643.0
# 22    101303.0
# 26    116970.0
# 18     81364.0
# 14     61112.0
# Name: Salary, dtype: float64

# %%
model.predict(x_test) # Predicting the test data's result
# Out:
# array([ 72349.74519846,  53512.61125108, 100605.44611953, 115675.15327744,
#         81768.31217215,  68582.31840899])

# %%
print("Here how the linear regration trained ===>>>")
plt.scatter(df['YearsExperience'] ,df['Salary'])
plt.plot(x_train, model.predict(x_train), color='green')
# Out:
# Here how the linear regration trained ===>>>

# %%
import seaborn as sns
sns.jointplot(x='YearsExperience', y='Salary', data=df, kind='reg', height=8);
plt.show();
